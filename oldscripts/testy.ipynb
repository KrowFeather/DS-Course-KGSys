# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
from langchain_community.graphs import Neo4jGraph

output_parser = StrOutputParser()
# graph = Neo4jGraph(
#     url="neo4j://localhost:7687",
#     username="neo4j",
#     password="12345678",
# )
llm = OllamaLLM(model="llama3.2")
prompt = ChatPromptTemplate.from_messages([
    ("system","你现在是一个中文问答助手，请以中文回答所有问题"),
    ("user", "{input}")
])
chain = prompt | llm | output_parser

print(chain.invoke({"input": "What is Neo4j?"}))
# Out:
# Neo4j 是一款开源图形数据库系统，尤其适合处理复杂关系数据。它是基于Graph Database的，是目前最受欢迎的一款图形数据库之一。
#
# 在 Neo4j 中，数据以 node 和 edge 的形式存储，每个 node 对应一个值，可以包含不同类型的属性。边则连接两个 node，表示关联或联系关系。
#
# Neo4j 的特点包括：
#
# 1. 高可扩展性：可以高效地处理大规模的关系数据。
# 2. 高性能： Neo4j 可以快速读写和查询数据。
# 3. 强大的 graphQL 支持：允许你使用图形数据库中的 query 语言来 queries 数据。
#
# Neo4j 被广泛用于各种应用场景，如：
#
# 1. 社交网络
# 2. recommending 系统
# 3. 知识图谱
# 4. 组织结构图
#
# 总的来说，Neo4j 是一种强大的、易于使用的图形数据库系统，适合处理复杂关系数据。

# %%
from langchain_community.graphs import Neo4jGraph

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
graph = Neo4jGraph(url='neo4j://localhost:7687',username='neo4j',password='12345678')

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader

loader = TextLoader(file_path="nbooks/test.txt")
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=24)
documents = text_splitter.split_documents(documents=docs)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_community\document_loaders\text.py:43, in TextLoader.lazy_load(self)
#      42     with open(self.file_path, encoding=self.encoding) as f:
# ---> 43         text = f.read()
#      44 except UnicodeDecodeError as e:
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0xa6 in position 16: illegal multibyte sequence
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 5
#       2 from langchain_community.document_loaders import TextLoader
#       4 loader = TextLoader(file_path="test.txt")
# ----> 5 docs = loader.load()
#       7 text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=24)
#       8 documents = text_splitter.split_documents(documents=docs)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\document_loaders\base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_community\document_loaders\text.py:56, in TextLoader.lazy_load(self)
#      54                 continue
#      55     else:
# ---> 56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
#      58     raise RuntimeError(f"Error loading {self.file_path}") from e
#
# RuntimeError: Error loading test.txt

# %%
from langchain_ollama import OllamaLLM
from langchain_experimental.graph_transformers import LLMGraphTransformer

llm = OllamaLLM(model="llama3.2")

llm_transformer = LLMGraphTransformer(llm=llm)

graph_documents = llm_transformer.convert_to_graph_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       4 llm = OllamaLLM(model="llama3.2", temperature=0, format="json")
#       6 llm_transformer = LLMGraphTransformer(llm=llm)
# ----> 8 graph_documents = llm_transformer.convert_to_graph_documents(documents)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_experimental\graph_transformers\llm.py:809, in LLMGraphTransformer.convert_to_graph_documents(self, documents, config)
#     797 def convert_to_graph_documents(
#     798     self, documents: Sequence[Document], config: Optional[RunnableConfig] = None
#     799 ) -> List[GraphDocument]:
#     800     """Convert a sequence of documents into graph documents.
#     801
#     802     Args:
#    (...)
#     807         Sequence[GraphDocument]: The transformed documents as graphs.
#     808     """
# --> 809     return [self.process_response(document, config) for document in documents]
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_experimental\graph_transformers\llm.py:809, in <listcomp>(.0)
#     797 def convert_to_graph_documents(
#     798     self, documents: Sequence[Document], config: Optional[RunnableConfig] = None
#     799 ) -> List[GraphDocument]:
#     800     """Convert a sequence of documents into graph documents.
#     801
#     802     Args:
#    (...)
#     807         Sequence[GraphDocument]: The transformed documents as graphs.
#     808     """
# --> 809     return [self.process_response(document, config) for document in documents]
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_experimental\graph_transformers\llm.py:739, in LLMGraphTransformer.process_response(self, document, config)
#     734 """
#     735 Processes a single document, transforming it into a graph document using
#     736 an LLM based on the model's schema and constraints.
#     737 """
#     738 text = document.page_content
# --> 739 raw_schema = self.chain.invoke({"input": text}, config=config)
#     740 if self._function_call:
#     741     raw_schema = cast(Dict[Any, Any], raw_schema)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\language_models\llms.py:390, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     380 def invoke(
#     381     self,
#     382     input: LanguageModelInput,
#    (...)
#     386     **kwargs: Any,
#     387 ) -> str:
#     388     config = ensure_config(config)
#     389     return (
# --> 390         self.generate_prompt(
#     391             [self._convert_input(input)],
#     392             stop=stop,
#     393             callbacks=config.get("callbacks"),
#     394             tags=config.get("tags"),
#     395             metadata=config.get("metadata"),
#     396             run_name=config.get("run_name"),
#     397             run_id=config.pop("run_id", None),
#     398             **kwargs,
#     399         )
#     400         .generations[0][0]
#     401         .text
#     402     )
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\language_models\llms.py:755, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     747 def generate_prompt(
#     748     self,
#     749     prompts: list[PromptValue],
#    (...)
#     752     **kwargs: Any,
#     753 ) -> LLMResult:
#     754     prompt_strings = [p.to_string() for p in prompts]
# --> 755     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\language_models\llms.py:950, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     935 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     936     run_managers = [
#     937         callback_manager.on_llm_start(
#     938             self._serialized,
#    (...)
#     948         )
#     949     ]
# --> 950     output = self._generate_helper(
#     951         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     952     )
#     953     return output
#     954 if len(missing_prompts) > 0:
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\language_models\llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     790     for run_manager in run_managers:
#     791         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 792     raise e
#     793 flattened_outputs = output.flatten()
#     794 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_core\language_models\llms.py:779, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     769 def _generate_helper(
#     770     self,
#     771     prompts: list[str],
#    (...)
#     775     **kwargs: Any,
#     776 ) -> LLMResult:
#     777     try:
#     778         output = (
# --> 779             self._generate(
#     780                 prompts,
#     781                 stop=stop,
#     782                 # TODO: support multiple run managers
#     783                 run_manager=run_managers[0] if run_managers else None,
#     784                 **kwargs,
#     785             )
#     786             if new_arg_supported
#     787             else self._generate(prompts, stop=stop)
#     788         )
#     789     except BaseException as e:
#     790         for run_manager in run_managers:
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_ollama\llms.py:304, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     302 generations = []
#     303 for prompt in prompts:
# --> 304     final_chunk = self._stream_with_aggregation(
#     305         prompt,
#     306         stop=stop,
#     307         run_manager=run_manager,
#     308         verbose=self.verbose,
#     309         **kwargs,
#     310     )
#     311     generations.append([final_chunk])
#     312 return LLMResult(generations=generations)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_ollama\llms.py:272, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     263 def _stream_with_aggregation(
#     264     self,
#     265     prompt: str,
#    (...)
#     269     **kwargs: Any,
#     270 ) -> GenerationChunk:
#     271     final_chunk = None
# --> 272     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     273         if not isinstance(stream_resp, str):
#     274             chunk = GenerationChunk(
#     275                 text=stream_resp["response"] if "response" in stream_resp else "",
#     276                 generation_info=(
#     277                     dict(stream_resp) if stream_resp.get("done") is True else None
#     278                 ),
#     279             )
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\langchain_ollama\llms.py:222, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     219         params[key] = kwargs[key]
#     221 params["options"]["stop"] = stop
# --> 222 yield from self._client.generate(
#     223     model=params["model"],
#     224     prompt=prompt,
#     225     stream=True,
#     226     options=Options(**params["options"]),
#     227     keep_alive=params["keep_alive"],
#     228     format=params["format"],
#     229 )
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\ollama\_client.py:87, in Client._stream(self, method, url, **kwargs)
#      84   e.response.read()
#      85   raise ResponseError(e.response.text, e.response.status_code) from None
# ---> 87 for line in r.iter_lines():
#      88   partial = json.loads(line)
#      89   if e := partial.get('error'):
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_models.py:861, in Response.iter_lines(self)
#     859 decoder = LineDecoder()
#     860 with request_context(request=self._request):
# --> 861     for text in self.iter_text():
#     862         for line in decoder.decode(text):
#     863             yield line
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_models.py:848, in Response.iter_text(self, chunk_size)
#     846 chunker = TextChunker(chunk_size=chunk_size)
#     847 with request_context(request=self._request):
# --> 848     for byte_content in self.iter_bytes():
#     849         text_content = decoder.decode(byte_content)
#     850         for chunk in chunker.decode(text_content):
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_models.py:829, in Response.iter_bytes(self, chunk_size)
#     827 chunker = ByteChunker(chunk_size=chunk_size)
#     828 with request_context(request=self._request):
# --> 829     for raw_bytes in self.iter_raw():
#     830         decoded = decoder.decode(raw_bytes)
#     831         for chunk in chunker.decode(decoded):
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_models.py:883, in Response.iter_raw(self, chunk_size)
#     880 chunker = ByteChunker(chunk_size=chunk_size)
#     882 with request_context(request=self._request):
# --> 883     for raw_stream_bytes in self.stream:
#     884         self._num_bytes_downloaded += len(raw_stream_bytes)
#     885         for chunk in chunker.decode(raw_stream_bytes):
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_client.py:126, in BoundSyncStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
# --> 126     for chunk in self._stream:
#     127         yield chunk
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpx\_transports\default.py:113, in ResponseStream.__iter__(self)
#     111 def __iter__(self) -> typing.Iterator[bytes]:
#     112     with map_httpcore_exceptions():
# --> 113         for part in self._httpcore_stream:
#     114             yield part
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_sync\connection_pool.py:361, in ConnectionPoolByteStream.__iter__(self)
#     360 def __iter__(self) -> Iterator[bytes]:
# --> 361     for part in self._stream:
#     362         yield part
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_sync\http11.py:337, in HTTP11ConnectionByteStream.__iter__(self)
#     335 with ShieldCancellation():
#     336     self.close()
# --> 337 raise exc
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_sync\http11.py:329, in HTTP11ConnectionByteStream.__iter__(self)
#     327 try:
#     328     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 329         for chunk in self._connection._receive_response_body(**kwargs):
#     330             yield chunk
#     331 except BaseException as exc:
#     332     # If we get an exception while streaming the response,
#     333     # we want to close the response (and possibly the connection)
#     334     # before raising that exception.
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_sync\http11.py:198, in HTTP11Connection._receive_response_body(self, request)
#     195 timeout = timeouts.get("read", None)
#     197 while True:
# --> 198     event = self._receive_event(timeout=timeout)
#     199     if isinstance(event, h11.Data):
#     200         yield bytes(event.data)
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\Anaconda\envs\DeepLearning\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
